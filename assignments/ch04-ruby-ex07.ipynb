# %% [markdown]
# # 例題7　線形探索で在庫数を調べるプログラム
# **4章4節　プログラミングの実践（Ruby版）**

# %%
# !ruby --version 2>/dev/null || (apt-get install -y ruby > /dev/null && ruby --version)

# %% [markdown]
# ## ✅ 使い方
# - `▶ ボタン` または `Shift+Enter` でセルを実行できる
# - `# ここを入力` の部分にプログラムを書いて埋めよう！
# - `# ★変えよう★` は値を変えて動作を確認できる
#
# > **📝 Colab での入力について**：本来 `gets.to_i` で入力するが，Colab では変数に直接値を代入して代用する。

# %% [markdown]
# ## 📖 学習内容：線形探索
#
# **探索**：たくさんのデータの中から目的のデータを探し出すこと。
# **線形探索**：最初のデータから順番に一つずつ調べていくアルゴリズム。
#
# | 変数名 | 格納する値 |
# |---|---|
# | `i` | 探索する添字 |
# | `n` | データ数 |
# | `srch_stck` | 探索対象の商品番号 |
#
# > `break` で繰り返しから抜け出せる。

# %% [markdown]
# ## 🎯 問題
#
# 下の在庫データから，商品番号を線形探索で探し，商品名と在庫数を表示するプログラムを作成してみよう。
#
# ### アルゴリズム
# 1. 探索する商品番号を `srch_stck` に代入
# 2. データ数を `n` に代入
# 3. `i` を0から `n-1` まで繰り返し
# 4. 　もし `stock[i][0]` が `srch_stck` と等しければ
# 5. 　　商品番号・商品名・在庫数を表示
# 6. 　　繰り返しを終了
#
# ### ヒント
# - `stock[i][0]` は i番目のデータの商品番号
# - `break` で繰り返しから抜け出す
# - `stock.length` で配列の要素数が取得できる

# %%
# %%bash
# ruby << 'RUBY'
# stock = [
#   [1001, "飲料水A",   87],
#   [1003, "飲料水B",   89],
#   [1004, "飲料水C",   52],
#   [1007, "飲料水D",  120],
#   [1011, "飲料水E",  119],
#   [2001, "菓子パンA", 67]
# ]
#
# # ① ★変えよう★（探したい商品番号）
# srch_stck = 1007
#
# # ② データ数を取得
# n = # ここを入力
#
# # ③ i を 0 から n-1 まで繰り返し
# for i in # ここを入力
#   # ④ 商品番号が一致するか判定
#   if # ここを入力
#     # ⑤ 商品番号・商品名・在庫数を表示
#     puts "#{stock[i][0]} #{stock[i][1]} #{stock[i][2]}"
#     # ⑥ 繰り返しを終了
#     # ここを入力
#   end
# end
#
# RUBY

# %% [markdown]
# ## ✏️ 確認問題
# 商品が見つからなかった場合に「見つかりませんでした」と表示するよう，プログラムを改良してみよう。

# %%
# %%bash
# ruby << 'RUBY'
# stock = [
#   [1001, "飲料水A",   87],
#   [1003, "飲料水B",   89],
#   [1004, "飲料水C",   52],
#   [1007, "飲料水D",  120],
#   [1011, "飲料水E",  119],
#   [2001, "菓子パンA", 67]
# ]
#
# srch_stck = 9999  # 存在しない商品番号
#
# # ★見つからなかった場合の処理も追加しよう★
# n = stock.length
# found = false
# for i in 0..n-1
#   if srch_stck == stock[i][0]
#     puts "#{stock[i][0]} #{stock[i][1]} #{stock[i][2]}"
#     found = true
#     break
#   end
# end
# # ここを入力（found が false なら「見つかりませんでした」を表示）
#
# RUBY
